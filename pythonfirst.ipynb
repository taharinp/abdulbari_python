# %%
length=14
print(length)
# Out:
# 14

# %%
prices=[10,2,45,78]
print(prices)
# Out:
# [10, 2, 45, 78]

# %%
name,price,qty='soap',13,33
print(name)
# Out:
# soap

# %%
a,b,c=1,1,1
print(id(a),id(b),id(c))
# Out:
# 140705035101096 140705035101096 140705035101096

# %%
a=b=c=1
print(a,b,c)
# Out:
# 1 1 1

# %% [markdown]
# a=13
# print(type(a))

# %%
a=13
print(type(a))
# Out:
# <class 'int'>

# %%
a1=10
print(a1)
# Out:
# 10

# %%
la=25
la
# Out:
# 25

# %%
abc123mnp=10

# %%
abc_def=10
