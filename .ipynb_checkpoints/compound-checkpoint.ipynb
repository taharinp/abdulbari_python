# %%
n=int(input('enter a number'))
if n%2==0:
 print('even')
else:
 print('odd')
# Out:
# enter a number 5
# odd

# %%
n=int(input('enter age'))
if n>=18:
    print('eligible')
else:
    print('not eligible')
# Out:
# enter age 45
# eligible

# %%
age=int(input('enter age'))
if age>=18 and age <=60:
    print('can work')
else:
    print('cant work')
# Out:
# enter age 358
# cant work
