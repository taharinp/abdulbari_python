# %%
s1='hello'

# %%
for x in s1:
    print(x)
# Out:
# h
# e
# l
# l
# o

# %%
for i in range (len(s1)):
    print(s1[i])
# Out:
# h
# e
# l
# l
# o

# %%
s1='hello world'

# %%
s2=s1[10:-5:-2]

# %%
s1[3:7]
# Out:
# 'lo w'

# %%
s1[:5]
# Out:
# 'hello'

# %% [markdown]
# s2=s1[10:5:-1]

# %%
s1[:]
# Out:
# 'hello world'

# %%
s1[-8:-4]
# Out:
# 'lo w'

# %%
s2=s1[ : :-1]

# %%
print(s2)
# Out:
# dlrow olleh

# %%
s1='woe'
s2='ewd'
s3=s1+s2
print(s3)
# Out:
# woeewd

# %%
s1='x'
s2=s1*10
print(s2)
# Out:
# xxxxxxxxxx

# %%
s1='absjwdw'
'a' in s1
# Out:
# True

# %%
'cde' in s1
# Out:
# False

# %%
'z' in s1
# Out:
# False
