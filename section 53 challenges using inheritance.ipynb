# %%
import heapq

# %%
l=[2,3,4,5,6,7]

# %%
heapq.heapify(l)

# %%
l
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
heapq.heappush(l,8)
l
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
heapq.heappop(l)
# Out:
# 2

# %%
heapq.nlargest(3,l)
# Out:
# [8, 7, 6]
