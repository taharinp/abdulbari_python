# %%
n=int(input('enter a number'))
if n%2==0:
 print('even')
else:
 print('odd')
# Out:
# enter a number 5
# odd

# %%
n=int(input('enter age'))
if n>=18:
    print('eligible')
else:
    print('not eligible')
# Out:
# enter age 45
# eligible

# %%
age=int(input('enter age'))
if age>=18 and age <=60:
    print('can work')
else:
    print('cant work')
# Out:
# enter age 358
# cant work

# %%
x=input('enter a lowercase letter')
if x=='a' or x=='e' or x=='i' or x=='o' or x=='u':
    print('vowel')
else:
    print('constant')
# Out:
# enter a lowercase letter e
# vowel

# %%
maths =int(input('enter marks'))
physics =int(input('enter marks'))
chem =int(input('enter marks'))
if maths>=45 and physics>=45 and chem>=45:
    print('pass')
else:
    print('fail')
# Out:
# enter marks 85
# enter marks 35
# enter marks 98
# fail

# %%
temp=float(input('enter temp'))
if temp==25:
    print('normal')
else:
    if temp<25:
        print('odd')
    else:
        print('hot')
# Out:
# enter temp 65
# hot
